# %%
# !pip3 install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\repos\ayrapetov\00_site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ayrapetov_es\appdata\roaming\python\python311\site-packages (from opencv-python) (1.26.4)

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv
from ultralytics import YOLO

# %%
bgr = cv.imread('image.jpg')
rgb = cv.cvtColor(bgr, cv.COLOR_BGR2RGB)

# %%
plt.imshow(rgb);

# %%
bgr = cv.imread('image.jpg')
gray = cv.cvtColor(bgr, cv.COLOR_BGR2GRAY)

# Применение фильтра Канни
edges = cv.Canny(gray, 50, 150, apertureSize = 3)

# Применение преобразования Хафа для обнаружения линий
lines = cv.HoughLinesP(edges, 1, np.pi / 180, threshold=100, minLineLength=10, maxLineGap=250)

# Рисуем линии на изображении
for line in lines:
    x1,y1,x2,y2 = line[0]
    cv.line(bgr, (x1, y1), (x2, y2), (0, 0, 255), 2)

# Показываем результат
print(len(lines))
plt.imshow(bgr)
# Out:
# 27

# %%
plt.imshow(edges, cmap='gray');
